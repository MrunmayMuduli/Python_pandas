# %%
import pandas as pd
import numpy as np

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /Users/mrunmay/Desktop/gapminder.csv
# 100%|██████████████████████████████████████| 83.8k/83.8k [00:00<00:00, 1.60MB/s]

# %%
df = pd.read_csv("/Users/mrunmay/Desktop/gapminder.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
temp = df.set_index("country")

# %%
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.loc["Afghanistan"]
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#Method 1
d = {"country":"India","year":2022,"population":1300000000,"continent":"Asia","life_exp":69,"gdp_cap":640}

# %%
df = df.append(d,ignore_index=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
# 1706        India  2022  1300000000      Asia    69.000  640.000000
# 1707        India  2022  1300000000      Asia    69.000  640.000000
#
# [1708 rows x 6 columns]

# %%
len(df.index)
# Out:
# 1708

# %%
#Method 2
df.loc[len(df.index)] = ["India",2018,1200000000,"Asia",71,600]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1705        India  2018  1200000000      Asia    71.000  600.000000
# 1706        India  2022  1300000000      Asia    69.000  640.000000
# 1707        India  2022  1300000000      Asia    69.000  640.000000
# 1708        India  2018  1200000000      Asia    71.000  600.000000
# 1709        India  2018  1200000000      Asia    71.000  600.000000
#
# [1710 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1705    False
# 1706     True
# 1707     True
# 1708     True
# 1709     True
# Length: 1710, dtype: bool

# %%
np.all(df.duplicated())
# Out:
# False

# %%
df[df.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1706   India  2022  1300000000      Asia      69.0    640.0
# 1707   India  2022  1300000000      Asia      69.0    640.0
# 1708   India  2018  1200000000      Asia      71.0    600.0
# 1709   India  2018  1200000000      Asia      71.0    600.0

# %%
df.loc[df.duplicated(),"country":"continent"]#Slicing
# Out:
#      country  year  population continent
# 1706   India  2022  1300000000      Asia
# 1707   India  2022  1300000000      Asia
# 1708   India  2018  1200000000      Asia
# 1709   India  2018  1200000000      Asia

# %%
df.loc[df.duplicated(),["country","population"]]#Two individual
# Out:
#      country  population
# 1706   India  1300000000
# 1707   India  1300000000
# 1708   India  1200000000
# 1709   India  1200000000

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1705        India  2018  1200000000      Asia    71.000  600.000000
# 1706        India  2022  1300000000      Asia    69.000  640.000000
# 1707        India  2022  1300000000      Asia    69.000  640.000000
# 1708        India  2018  1200000000      Asia    71.000  600.000000
# 1709        India  2018  1200000000      Asia    71.000  600.000000
#
# [1710 rows x 6 columns]

# %%
df.drop_duplicates(keep="first")
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
#
# [1706 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1705        India  2018  1200000000      Asia    71.000  600.000000
# 1706        India  2022  1300000000      Asia    69.000  640.000000
# 1707        India  2022  1300000000      Asia    69.000  640.000000
# 1708        India  2018  1200000000      Asia    71.000  600.000000
# 1709        India  2018  1200000000      Asia    71.000  600.000000
#
# [1710 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
#
# [1706 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1705        India  2018  1200000000      Asia    71.000  600.000000
# 1706        India  2022  1300000000      Asia    69.000  640.000000
# 1707        India  2022  1300000000      Asia    69.000  640.000000
# 1708        India  2018  1200000000      Asia    71.000  600.000000
# 1709        India  2018  1200000000      Asia    71.000  600.000000
#
# [1710 rows x 6 columns]

# %%
df.drop_duplicates(keep="last",inplace=True,ignore_index=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
#
# [1706 rows x 6 columns]

# %%
df.tail(5)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2022  1300000000      Asia    69.000  640.000000
# 1705     India  2018  1200000000      Asia    71.000  600.000000

# %%
df.iloc[-1]
# Out:
# country            India
# year                2018
# population    1200000000
# continent           Asia
# life_exp            71.0
# gdp_cap            600.0
# Name: 1705, dtype: object

# %%
le = df["life_exp"]

# %%
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1701    46.809
# 1702    39.989
# 1703    43.487
# 1704    69.000
# 1705    71.000
# Name: life_exp, Length: 1706, dtype: float64

# %%
le.sum()
# Out:
# 101484.44467999999

# %%
sum(le)
# Out:
# 101484.44467999993

# %%
le.count()
# Out:
# 1706

# %%
le.min()
# Out:
# 23.599

# %%
le.max()
# Out:
# 82.603

# %%
le.mean()
# Out:
# 59.48677882766702

# %%
le.sum()/le.count()
# Out:
# 59.48677882766705

# %%
df.sort_values("year")
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 564            Germany  1952    69145952    Europe    67.500   7144.114393
# 576              Ghana  1952     5581001    Africa    43.149    911.298937
# 588             Greece  1952     7733250    Europe    65.860   3530.690067
# ...                ...   ...         ...       ...       ...           ...
# 71           Australia  2007    20434176   Oceania    81.235  34435.367440
# 839   Korea, Dem. Rep.  2007    23301725      Asia    67.297   1593.065480
# 911              Libya  2007     6036914    Africa    73.952  12057.499280
# 1705             India  2018  1200000000      Asia    71.000    600.000000
# 1704             India  2022  1300000000      Asia    69.000    640.000000
#
# [1706 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
#
# [1706 rows x 6 columns]

# %%
df.sort_values(["year"],ascending=False)
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 1704           India  2022  1300000000      Asia    69.000    640.000000
# 1705           India  2018  1200000000      Asia    71.000    600.000000
# 1523        Tanzania  2007    38139640    Africa    52.517   1107.482182
# 755          Ireland  2007     4109086    Europe    78.885  40675.996350
# 1451           Sudan  2007    42292929    Africa    58.556   2602.394995
# ...              ...   ...         ...       ...       ...           ...
# 612           Guinea  1952     2664249    Africa    33.609    510.196492
# 1596  United Kingdom  1952    50430000    Europe    69.180   9979.508487
# 1164        Pakistan  1952    41346560      Asia    43.436    684.597144
# 600        Guatemala  1952     3146381  Americas    42.023   2428.237769
# 0        Afghanistan  1952     8425333      Asia    28.801    779.445314
#
# [1706 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2022  1300000000      Asia    69.000  640.000000
# 1705        India  2018  1200000000      Asia    71.000  600.000000
#
# [1706 rows x 6 columns]

# %%
df.sort_values(["year","life_exp"],ascending=[False,True])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1704        India  2022  1300000000      Asia    69.000    640.000000
# 1705        India  2018  1200000000      Asia    71.000    600.000000
# 1463    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1043   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1691       Zambia  2007    11746035    Africa    42.384   1271.211593
# ...           ...   ...         ...       ...       ...           ...
# 408       Denmark  1952     4334000    Europe    70.780   9692.385245
# 1464       Sweden  1952     7124673    Europe    71.860   8527.844662
# 1080  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 684       Iceland  1952      147962    Europe    72.490   7267.688428
# 1140       Norway  1952     3327728    Europe    72.670  10095.421720
#
# [1706 rows x 6 columns]

# %%
a = pd.DataFrame([[10,20,30],[20,30,40]],columns=["A","B","C"])#Row wise
print(a)
# Out:
#     A   B   C
# 0  10  20  30
# 1  20  30  40

# %%
b = pd.DataFrame({"A":[20,30],"B":[40,50]})#Col wise
print(b)
# Out:
#     A   B
# 0  20  40
# 1  30  50

# %%
pd.concat([a,b],axis=0)
# Out:
#     A   B     C
# 0  10  20  30.0
# 1  20  30  40.0
# 0  20  40   NaN
# 1  30  50   NaN

# %%
pd.concat([a,b],ignore_index=True)
# Out:
#     A   B     C
# 0  10  20  30.0
# 1  20  30  40.0
# 2  20  40   NaN
# 3  30  50   NaN

# %%
pd.concat([a,b],keys=["X","Y"])#index
# Out:
#       A   B     C
# X 0  10  20  30.0
#   1  20  30  40.0
# Y 0  20  40   NaN
#   1  30  50   NaN

# %%
pd.concat([a,b],join="outer")
# Out:
#     A   B     C
# 0  10  20  30.0
# 1  20  30  40.0
# 0  20  40   NaN
# 1  30  50   NaN

# %%
pd.concat([a,b],join="inner")
# Out:
#     A   B
# 0  10  20
# 1  20  30
# 0  20  40
# 1  30  50

# %%
pd.concat([a,b],join="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qf/b_1clwxx1f11gyqwhwkz9lrh0000gn/T/ipykernel_29357/2293789873.py in <module>
# ----> 1 pd.concat([a,b],join="left")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ...

# %%
users = pd.DataFrame([[1,"Mrunmay"],[2,"Sony"],[3,"Max"]],columns=["UserID","Name"])
print(users)
# Out:
#    UserID     Name
# 0       1  Mrunmay
# 1       2     Sony
# 2       3      Max

# %%
msgs = pd.DataFrame({"UserID":[1,1,3],"message":["Good","Bye","Mrng"]})
print(msgs)
# Out:
#    UserID message
# 0       1    Good
# 1       1     Bye
# 2       3    Mrng

# %%
users.merge(msgs)
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       3      Max    Mrng

# %%
users.merge(msgs,on="UserID")#Use this. We need to mention "on"
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       3      Max    Mrng

# %%
users.merge(msgs,on="UserID",how="outer")
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       2     Sony     NaN
# 3       3      Max    Mrng

# %%
users.merge(msgs,on="UserID",how="inner")
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       3      Max    Mrng

# %%
users.merge(msgs,on="UserID",how="left")
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       2     Sony     NaN
# 3       3      Max    Mrng

# %%
users.merge(msgs,on="UserID",how="right")
# Out:
#    UserID     Name message
# 0       1  Mrunmay    Good
# 1       1  Mrunmay     Bye
# 2       3      Max    Mrng

# %%
users.rename(columns={"UserID":"ID"},inplace=True)

# %%
users
# Out:
#    ID     Name
# 0   1  Mrunmay
# 1   2     Sony
# 2   3      Max

# %%
users.merge(msgs,left_on="ID",right_on="UserID",how="outer")
# Out:
#    ID     Name  UserID message
# 0   1  Mrunmay     1.0    Good
# 1   1  Mrunmay     1.0     Bye
# 2   2     Sony     NaN     NaN
# 3   3      Max     3.0    Mrng

# %%
users.merge(msgs,left_on="ID",right_on="UserID",how="inner")
# Out:
#    ID     Name  UserID message
# 0   1  Mrunmay       1    Good
# 1   1  Mrunmay       1     Bye
# 2   3      Max       3    Mrng

# %%
users.merge(msgs,left_on="ID",right_on="UserID",how="left")
# Out:
#    ID     Name  UserID message
# 0   1  Mrunmay     1.0    Good
# 1   1  Mrunmay     1.0     Bye
# 2   2     Sony     NaN     NaN
# 3   3      Max     3.0    Mrng

# %%
users.merge(msgs,left_on="ID",right_on="UserID",how="right")
# Out:
#    ID     Name  UserID message
# 0   1  Mrunmay       1    Good
# 1   1  Mrunmay       1     Bye
# 2   3      Max       3    Mrng

# %%
#Another dataset

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /Users/mrunmay/Desktop/movies.csv
# 100%|████████████████████████████████████████| 112k/112k [00:00<00:00, 2.89MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /Users/mrunmay/Desktop/directors.csv
# 100%|██████████████████████████████████████| 65.4k/65.4k [00:00<00:00, 1.86MB/s]

# %%
movies=pd.read_csv("/Users/mrunmay/Desktop/movies.csv",index_col=0)
directors=pd.read_csv("/Users/mrunmay/Desktop/directors.csv",index_col=0)

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 5     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 4736  48363          0           3      321952
# 4743  48370      27000          19     3151130
# 4748  48375          0           7           0
# 4749  48376          0           3           0
# 4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies["director_id"].unique()
# Out:
# array([4762, 4763, 4764, 4765, 4767, 4771, 4772, 4773, 4774, 4775, 4776,
#        4777, 4779, 4780, 4782, 4785, 4786, 4788, 4791, 4793, 4794, 4797,
#        4798, 4799, 4802, 4803, 4804, 4805, 4808, 4809, 4810, 4811, 4812,
#        4813, 4814, 4829, 4831, 4832, 4833, 4838, 4839, 4842, 4845, 4846,
#        4847, 4849, 4854, 4857, 4858, 4859, 4863, 4865, 4866, 4867, 4868,
#        4872, 4873, 4874, 4876, 4880, 4881, 4885, 4886, 4888, 4889, 4890,
#        4892, 4893, 4894, 4900, 4904, 4909, 4913, 4915, 4917, 4918, 4921,
#        4923, 4924, 4925, 4926, 4927, 4930, 4935, 4936, 4945, 4947, 4948,
#        4949, 4955, 4958, 4960, 4964, 4965, 4967, 4974, 4978, 4989, 4991,
#        4993, 4995, 4998, 5002, 5005, 5008, 5009, 5014, 5017, 5024, 5031,
#        5033, 5034, 5035, 5037, 5039, 5047, 5053, 5056, 5059, 5061, 5067,
#        5082, 5087, 5088, 5093, 5096, 5097, 5101, 5105, 5111, 5113, 5115,
#        5116, 5123, 5125, 5130, 5132, 5135, 5140, 5147, 5148, 5152, 5157,
# ...

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
movies["director_id"].value_counts()
# Out:
# 4799    26
# 4809    19
# 5087    19
# 5457    18
# 4779    16
#         ..
# 5105     5
# 4849     5
# 5096     5
# 5088     5
# 6204     5
# Name: director_id, Length: 199, dtype: int64

# %%
directors["id"].value_counts()
# Out:
# 4762    1
# 6340    1
# 6324    1
# 6325    1
# 6326    1
#        ..
# 5546    1
# 5547    1
# 5548    1
# 5549    1
# 7110    1
# Name: id, Length: 2349, dtype: int64

# %%
directors["id"].nunique()
# Out:
# 2349

# %%
movies["director_id"].isin(directors["id"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
data=movies.merge(directors,left_on="director_id",right_on="id",how="outer")

# %%
data
# Out:
#          id_x       budget  popularity       revenue  \
# 0     43597.0  237000000.0       150.0  2.787965e+09
# 1     43622.0  200000000.0       100.0  1.845034e+09
# 2     43876.0  100000000.0       101.0  5.200000e+08
# 3     43879.0  115000000.0        38.0  3.788824e+08
# 4     44184.0   70000000.0        24.0  9.000010e+07
# ...       ...          ...         ...           ...
# 3610      NaN          NaN         NaN           NaN
# 3611      NaN          NaN         NaN           NaN
# 3612      NaN          NaN         NaN           NaN
# 3613      NaN          NaN         NaN           NaN
# 3614      NaN          NaN         NaN           NaN
#
#                            title  vote_average  vote_count  director_id  \
# 0                         Avatar           7.2     11800.0       4762.0
# 1                        Titanic           7.5      7562.0       4762.0
# 2     Terminator 2: Judgment Day           7.7      4185.0       4762.0
# ...

# %%
data=movies.merge(directors,left_on="director_id",right_on="id",how="inner")

# %%
data
# Out:
#        id_x     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
# ...     ...        ...         ...         ...                         ...
# 1460  46859          0          14    25288872                 Enough Said
# 1461  47023    6500000          11    13368437          Friends with Money
# 1462  47524    3000000           5           0                 Please Give
# 1463  47962          0           0           0         Walking and Talking
# 1464  48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
data=movies.merge(directors,left_on="director_id",right_on="id",how="left")

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data=movies.merge(directors,left_on="director_id",right_on="id",how="right")

# %%
data
# Out:
#          id_x       budget  popularity       revenue  \
# 0     43597.0  237000000.0       150.0  2.787965e+09
# 1     43622.0  200000000.0       100.0  1.845034e+09
# 2     43876.0  100000000.0       101.0  5.200000e+08
# 3     43879.0  115000000.0        38.0  3.788824e+08
# 4     44184.0   70000000.0        24.0  9.000010e+07
# ...       ...          ...         ...           ...
# 3610      NaN          NaN         NaN           NaN
# 3611      NaN          NaN         NaN           NaN
# 3612      NaN          NaN         NaN           NaN
# 3613      NaN          NaN         NaN           NaN
# 3614      NaN          NaN         NaN           NaN
#
#                            title  vote_average  vote_count  director_id  \
# 0                         Avatar           7.2     11800.0       4762.0
# 1                        Titanic           7.5      7562.0       4762.0
# 2     Terminator 2: Judgment Day           7.7      4185.0       4762.0
# ...
